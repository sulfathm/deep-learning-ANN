# %%
import tensorflow  as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.models import Sequential
from keras.layers import Dense
from sklearn.metrics import confusion_matrix

# %%
data=pd.read_csv("/content/drive/MyDrive/heart.csv")
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data.isnull().any()
# Out:
# age         False
# sex         False
# cp          False
# trestbps    False
# chol        False
# fbs         False
# restecg     False
# thalach     False
# exang       False
# oldpeak     False
# slope       False
# ca          False
# thal        False
# target      False
# dtype: bool

# %%
x=data.iloc[:,:13].values
y=data['target'].values

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=0)

# %%
from sklearn.preprocessing import StandardScaler
ssc=StandardScaler()
x_train=ssc.fit_transform(x_train)
x_test=ssc.transform(x_test)

# %%
classifier=Sequential()
classifier.add(Dense(activation='relu',input_dim=13,units=8,kernel_initializer='uniform'))
classifier.add(Dense(activation='relu' , units=14, kernel_initializer='uniform'))
classifier.add(Dense(activation='sigmoid', units=1, kernel_initializer='uniform'))
classifier.compile(optimizer='adam' , loss='binary_crossentropy', metrics=['accuracy'])

# %%
classifier.fit(x_train ,y_train ,batch_size=8 , epochs=100)
# Out:
# Epoch 1/100
# 27/27 [==============================] - 1s 2ms/step - loss: 0.6926 - accuracy: 0.5519
# Epoch 2/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6887 - accuracy: 0.5566
# Epoch 3/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6735 - accuracy: 0.6368
# Epoch 4/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6344 - accuracy: 0.7972
# Epoch 5/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5705 - accuracy: 0.8349
# Epoch 6/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.8396
# Epoch 7/100
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4426 - accuracy: 0.8491
# Epoch 8/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4003 - accuracy: 0.8632
# Epoch 9/100
# 27/27 [==============================] - 0s 2ms/step - loss: 0.3711 - accuracy: 0.8585
# Epoch 10/100
# ...

# %%
y_pred=classifier.predict(x_test)
y_pred=(y_pred > 0.5)
# Out:
# 3/3 [==============================] - 0s 4ms/step

# %%
y_pred
# Out:
# array([[False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [False],
#        [False],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
#        [ True],
# ...

# %%
a=int(input("age :"))
b=int(input("sex :"))
c=int(input("cp :"))
d=int(input("trestbps :"))
e=int(input("chol	:"))
f=int(input("fbs :"))
g=int(input("	restecg	:"))
h=int(input("thalach :"))
i=int(input("exang	:"))
j=int(input("oldpeak :"))
k=int(input("slope	 :"))
l=int(input("ca	:"))
m=int(input("thal	:"))
df=pd.DataFrame({"age":[a],
                 "sex":[b],
                 "cp":[c],
                 "trestbps":[d],
                 "chol":[e],
                 "fbs":[f],
                 "restecg":[g],
                 "thalach":[h],
                 "exang":[i],
                 "oldpeak":[j],
                 "slope":[k],
                 "ca":[l],
                 "thal":[m]})
df
# Out:
# age :57
# sex :0
# cp :0
# trestbps :140
# chol	:241
# fbs :0
# 	restecg	:1
# thalach :123
# exang	:1
# oldpeak :0
# slope	 :1
# ca	:0
# thal	:3
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   57    0   0       140   241    0        1      123      1        0      1
#
#    ca  thal
# 0   0     3

# %%
y_predict=classifier.predict(df)
y_predict
y_predict=(y_pred > 0.5)
if y_predict==[[1.]]:
  print("True")
else:
  print("False")
# Out:
# 1/1 [==============================] - 0s 56ms/step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-bf522c0b474a> in <module>
#       2 y_predict
#       3 y_predict=(y_pred > 0.5)
# ----> 4 if y_predict==[[1.]]:
#       5   print("True")
#       6 else:
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
\145a=int(input("age :"))
b=int(input("sex :"))
c=int(input("cp :"))
d=int(input("trestbps :"))
e=int(input("chol	:"))
f=int(input("fbs :"))
g=int(input("	restecg	:"))
h=int(input("thalach :"))
i=int(input("exang	 :"))
j=int(input("oldpeak :"))
k=int(input("slope	 :"))
l=int(input("ca	:"))
m=int(input("thal	:"))
df1=pd.DataFrame({"age":[a],
                 "sex":[b],
                 "cp":[c],
                 "trestbps":[d],
                 "chol":[e],
                 "fbs":[f],
                 "restecg":[g],
                 "thalach":[h],
                 "exang":[i],
                 "oldpeak":[j],
                 "slope":[k],
                 "ca":[l],
                 "thal":[m]})
df1

# %%
y_prediction=classifier.predict(df1)
y_prediction

# if y_prediction==[[1.]]:
#   print("True")
# else:
#   print("False")

# %%
a=int(input("age :"))
b=int(input("sex :"))
c=int(input("cp :"))
d=int(input("trestbps :"))
e=int(input("chol	:"))
f=int(input("fbs :"))
g=int(input("	restecg	:"))
h=int(input("thalach :"))
i=int(input("exang	 :"))
j=int(input("oldpeak :"))
k=int(input("slope	 :"))
l=int(input("ca	:"))
m=int(input("thal	:"))
df2=pd.DataFrame({"age":[a],
                 "sex":[b],
                 "cp":[c],
                 "trestbps":[d],
                 "chol":[e],
                 "fbs":[f],
                 "restecg":[g],
                 "thalach":[h],
                 "exang":[i],
                 "oldpeak":[j],
                 "slope":[k],
                 "ca":[l],
                 "thal":[m]})
df2

# %%
y_prd=classifier.predict(df2)
y_prd

# %%
a=int(input("age :"))
b=int(input("sex :"))
c=int(input("cp :"))
d=int(input("trestbps :"))
e=int(input("chol	:"))
f=int(input("fbs :"))
g=int(input("	restecg	:"))
h=int(input("thalach :"))
i=int(input("exang	 :"))
j=int(input("oldpeak :"))
k=int(input("slope	 :"))
l=int(input("ca	:"))
m=int(input("thal	:"))
df3=pd.DataFrame({"age":[a],
                 "sex":[b],
                 "cp":[c],
                 "trestbps":[d],
                 "chol":[e],
                 "fbs":[f],
                 "restecg":[g],
                 "thalach":[h],
                 "exang":[i],
                 "oldpeak":[j],
                 "slope":[k],
                 "ca":[l],
                 "thal":[m]})
df3

# %%
1y_pred=classifier.predict(df3)
y_pred

# %%
1
